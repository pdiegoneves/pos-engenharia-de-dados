# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
arr_1d = np.array([1, 2, 3, 4, 5])
print(f"Array 1D: {arr_1d}")
print(f"Tipo do Array: {type(arr_1d)}")
print(f"Dimensões do Array: {arr_1d.ndim}")
# Out:
# Array 1D: [1 2 3 4 5]
# Tipo do Array: <class 'numpy.ndarray'>
# Dimensões do Array: 1

# %%
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])
print(f"Array 2D: {arr_2d}")
print(f"Tipo do Array: {type(arr_2d)}")
print(f"Dimensões do Array: {arr_2d.ndim}")
# Out:
# Array 2D: [[1 2 3]
#  [4 5 6]]
# Tipo do Array: <class 'numpy.ndarray'>
# Dimensões do Array: 2
